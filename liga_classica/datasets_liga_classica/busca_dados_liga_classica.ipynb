# %% [markdown]
# ## Importações e Configuração Inicial
#  - AJUSTAR PARA BUSCAR INFORMAÇÕES DE PONTUAÇÕES MENSAIS

# %%
import cartolafc
import pandas as pd
from difflib import get_close_matches
import json
import time

pd.set_option('display.max_columns', 50)            # permite a visualização de 50 colunas do dataframe
pd.options.display.float_format = '{:.2f}'.format   # pandas: para todos os números aparecerem com duas casas decimais

# Cria uma instância da API
api = cartolafc.Api(attempts=5)
# Out:
# 2025-04-14 12:20:21,697 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.

# %%
nomes_times = ["Real SCI", "Gig@ntte", "PraiaBravaFC", "OlhaEleAiF.C!", "Gremiomaniasm", "Sport Clube PAIM", "PUXE FC", "RS Expressões da Arte", "ZIVI FC", "O clube do povo Itaqui/Rss",
               "F.C. Rei Das Copas", "Rolo Compressor ZN", "Taura da Fronteira FCIII", "Eleis-Itaqui", "KING LEONN", "Laranjja Mecannica", "Fedato Futebol Clube", "Perronee F.C", "Pity10", "pra sempre imortal fc",
               "RHANKA DENTY FC25", "TEAM LOPES 99", "pura bucha /botafogo", "cartola scheuer", "Remo Santo Ângelo", "Analove10 ITAQUI GRANDE!!", "DM Studio", "lsauer fc", "VASCO MARTINS FC", "KP JUV.",
               "BORGES ITAQUI F.C.", "Profit Soccer", "Tabajara de Inhaua FC2", "TIGRE LEON", "S.E.R. GRILLO", "seralex", "E.C. Bororé", "Texas Club 2025", "MAFRA MARTINS FC", "BordonFC",
               "Tatols Beants F.C", "FIGUEIRA DA ILHA", "MauHumor F.C.", "A Lenda Super Vascão f.c", "TATITTA FC", "HS SPORTS F.C", "FBC Colorado", "Dom Camillo68", "mercearia Estrela", "CosmoCity ZO",
               "clarinvalau fc", "Grêmio imortal 37", "SERGRILLO", "Super Vasco f.c", "A Lenda Super Vasco F.c", "Paulo Virgili FC", "CALOMBO ITAQUI RS", "Luis lemes inter", "emer jr fc", "Cril Futebol Club"]


# Dicionário para armazenar os IDs dos times
ids_times = {}

# Função para buscar o ID de um time pelo nome usando correspondência flexível
def buscar_id_time(nome_time):
    try:
        times = api.times(query=nome_time)
        nomes_api = [time.nome for time in times]
        nome_proximo = get_close_matches(nome_time, nomes_api, n=1, cutoff=0.6)
        if nome_proximo:
            for time in times:
                if time.nome == nome_proximo[0]:
                    return time.id
    except cartolafc.errors.CartolaFCError as e:
        print(f"Erro ao buscar ID para o time {nome_time}: {e}")
    return None

# Buscar os IDs dos times pelo nome
for nome in nomes_times:
    time_id = buscar_id_time(nome)
    if time_id:
        ids_times[nome] = time_id
    else:
        print(f"Não foi possível encontrar o ID para o time {nome}")

print(nomes_times)
# Out:
# Não foi possível encontrar o ID para o time Remo Santo Ângelo
# ['Real SCI', 'Gig@ntte', 'PraiaBravaFC', 'OlhaEleAiF.C!', 'Gremiomaniasm', 'Sport Clube PAIM', 'PUXE FC', 'RS Expressões da Arte', 'ZIVI FC', 'O clube do povo Itaqui/Rss', 'F.C. Rei Das Copas', 'Rolo Compressor ZN', 'Taura da Fronteira FCIII', 'Eleis-Itaqui', 'KING LEONN', 'Laranjja Mecannica', 'Fedato Futebol Clube', 'Perronee F.C', 'Pity10', 'pra sempre imortal fc', 'RHANKA DENTY FC25', 'TEAM LOPES 99', 'pura bucha /botafogo', 'cartola scheuer', 'Remo Santo Ângelo', 'Analove10 ITAQUI GRANDE!!', 'DM Studio', 'lsauer fc', 'VASCO MARTINS FC', 'KP JUV.', 'BORGES ITAQUI F.C.', 'Profit Soccer', 'Tabajara de Inhaua FC2', 'TIGRE LEON', 'S.E.R. GRILLO', 'seralex', 'E.C. Bororé', 'Texas Club 2025', 'MAFRA MARTINS FC', 'BordonFC', 'Tatols Beants F.C', 'FIGUEIRA DA ILHA', 'MauHumor F.C.', 'A Lenda Super Vascão f.c', 'TATITTA FC', 'HS SPORTS F.C', 'FBC Colorado', 'Dom Camillo68', 'mercearia Estrela', 'CosmoCity ZO', 'clarinvalau fc', 'Grêmio imortal 37', 'SERGRILLO', 'Super Vasco f.c', 'A Lenda Super Vasco F.c', 'Paulo Virgili FC', 'CALOMBO ITAQUI RS', 'Luis lemes inter', 'emer jr fc', 'Cril Futebol Club']

# %%
# Gerar DataFrame com nome do time, ID e URL
df_urls = pd.DataFrame([
    {"Nome do Time": nome, "ID do Time": time_id, "Link do Time": f"https://cartola.globo.com/#!/time/{time_id}"}
    for nome, time_id in ids_times.items()
])

# Caminho e nome do arquivo Excel
caminho_excel = "links_times_cartola_liga_classica.xlsx"

# Salvar o DataFrame em Excel
df_urls.to_excel(caminho_excel, index=False)

print(f"✅ Arquivo salvo com sucesso: {caminho_excel}")


# Exibir como tabela
display(df_urls)
# Out:
# ✅ Arquivo salvo com sucesso: links_times_cartola_liga_classica.xlsx
#                   Nome do Time  ID do Time  \
# 0                     Real SCI     3246608
# 1                     Gig@ntte    18421230
# 2                 PraiaBravaFC    47546604
# 3                OlhaEleAiF.C!     3708025
# 4                Gremiomaniasm      528730
# 5             Sport Clube PAIM     1148959
# 6                      PUXE FC     3447341
# 7        RS Expressões da Arte      896842
# 8                      ZIVI FC    29199152
# 9   O clube do povo Itaqui/Rss    14227419
# 10          F.C. Rei Das Copas      159074
# 11          Rolo Compressor ZN    18223508
# 12    Taura da Fronteira FCIII    28676425
# 13                Eleis-Itaqui      216066
# 14                  KING LEONN    13951133
# 15          Laranjja Mecannica    18344271
# 16        Fedato Futebol Clube    18642587
# 17                Perronee F.C     2760207
# 18                      Pity10    48498051
# 19       pra sempre imortal fc    25313333
# 20           RHANKA DENTY FC25    29411306
# 21               TEAM LOPES 99      479510
# 22        pura bucha /botafogo    18661583
# 23             cartola scheuer     3851966
# 24   Analove10 ITAQUI GRANDE!!    44574236
# 25                   DM Studio      387186
# 26                   lsauer fc    44810918
# 27            VASCO MARTINS FC    14696986
# 28                     KP JUV.    18346776
# 29          BORGES ITAQUI F.C.     3914981
# 30               Profit Soccer     9823692
# 31      Tabajara de Inhaua FC2    47543456
# 32                  TIGRE LEON     3424598
# 33               S.E.R. GRILLO     5823700
# 34                     seralex    29228373
# 35                 E.C. Bororé     6148913
# 36             Texas Club 2025     1273719
# 37            MAFRA MARTINS FC     4911779
# 38                    BordonFC     2602301
# 39           Tatols Beants F.C      212042
# 40            FIGUEIRA DA ILHA    25565675
# 41               MauHumor F.C.    25751748
# 42    A Lenda Super Vascão f.c    49355335
# 43                  TATITTA FC    49180400
# 44               HS SPORTS F.C    17887202
# 45                FBC Colorado      186283
# 46               Dom Camillo68    20696550
# 47           mercearia Estrela    25401606
# 48                CosmoCity ZO    44536510
# 49              clarinvalau fc     8319052
# 50           Grêmio imortal 37    24468241
# 51                   SERGRILLO    25811332
# 52             Super Vasco f.c    13707047
# 53     A Lenda Super Vasco F.c      117598
# 54            Paulo Virgili FC    14124559
# 55           CALOMBO ITAQUI RS     8707471
# 56            Luis lemes inter    20340994
# 57                  emer jr fc    50189029
# 58           Cril Futebol Club     5664592
#
#                                   Link do Time
# 0    https://cartola.globo.com/#!/time/3246608
# 1   https://cartola.globo.com/#!/time/18421230
# 2   https://cartola.globo.com/#!/time/47546604
# 3    https://cartola.globo.com/#!/time/3708025
# 4     https://cartola.globo.com/#!/time/528730
# 5    https://cartola.globo.com/#!/time/1148959
# 6    https://cartola.globo.com/#!/time/3447341
# 7     https://cartola.globo.com/#!/time/896842
# 8   https://cartola.globo.com/#!/time/29199152
# 9   https://cartola.globo.com/#!/time/14227419
# 10    https://cartola.globo.com/#!/time/159074
# 11  https://cartola.globo.com/#!/time/18223508
# 12  https://cartola.globo.com/#!/time/28676425
# 13    https://cartola.globo.com/#!/time/216066
# 14  https://cartola.globo.com/#!/time/13951133
# 15  https://cartola.globo.com/#!/time/18344271
# 16  https://cartola.globo.com/#!/time/18642587
# 17   https://cartola.globo.com/#!/time/2760207
# 18  https://cartola.globo.com/#!/time/48498051
# 19  https://cartola.globo.com/#!/time/25313333
# 20  https://cartola.globo.com/#!/time/29411306
# 21    https://cartola.globo.com/#!/time/479510
# 22  https://cartola.globo.com/#!/time/18661583
# 23   https://cartola.globo.com/#!/time/3851966
# 24  https://cartola.globo.com/#!/time/44574236
# 25    https://cartola.globo.com/#!/time/387186
# 26  https://cartola.globo.com/#!/time/44810918
# 27  https://cartola.globo.com/#!/time/14696986
# 28  https://cartola.globo.com/#!/time/18346776
# 29   https://cartola.globo.com/#!/time/3914981
# 30   https://cartola.globo.com/#!/time/9823692
# 31  https://cartola.globo.com/#!/time/47543456
# 32   https://cartola.globo.com/#!/time/3424598
# 33   https://cartola.globo.com/#!/time/5823700
# 34  https://cartola.globo.com/#!/time/29228373
# 35   https://cartola.globo.com/#!/time/6148913
# 36   https://cartola.globo.com/#!/time/1273719
# 37   https://cartola.globo.com/#!/time/4911779
# 38   https://cartola.globo.com/#!/time/2602301
# 39    https://cartola.globo.com/#!/time/212042
# 40  https://cartola.globo.com/#!/time/25565675
# 41  https://cartola.globo.com/#!/time/25751748
# 42  https://cartola.globo.com/#!/time/49355335
# 43  https://cartola.globo.com/#!/time/49180400
# 44  https://cartola.globo.com/#!/time/17887202
# 45    https://cartola.globo.com/#!/time/186283
# 46  https://cartola.globo.com/#!/time/20696550
# 47  https://cartola.globo.com/#!/time/25401606
# 48  https://cartola.globo.com/#!/time/44536510
# 49   https://cartola.globo.com/#!/time/8319052
# 50  https://cartola.globo.com/#!/time/24468241
# 51  https://cartola.globo.com/#!/time/25811332
# 52  https://cartola.globo.com/#!/time/13707047
# 53    https://cartola.globo.com/#!/time/117598
# 54  https://cartola.globo.com/#!/time/14124559
# 55   https://cartola.globo.com/#!/time/8707471
# 56  https://cartola.globo.com/#!/time/20340994
# 57  https://cartola.globo.com/#!/time/50189029
# 58   https://cartola.globo.com/#!/time/5664592

# %%
# Obter a rodada atual do mercado
rodada_atual = api.mercado().rodada_atual

print("Rodada Atual:", rodada_atual)
# Out:
# Rodada Atual: 4

# %% [markdown]
# ## Obter Pontuações por Rodada

# %%
# # Obter a rodada atual do mercado
# rodada_atual = api.mercado().rodada_atual

# # Função para verificar se o campeonato já começou (há pontuação na rodada 1)
# def campeonato_comecou(ids_times):
#     for time_id in ids_times.values():
#         try:
#             pontuacao = api.time(time_id=time_id, rodada=1).ultima_pontuacao
#             if pontuacao is not None:
#                 return True
#         except cartolafc.errors.CartolaFCError:
#             continue
#     return False

# # Verifica se o campeonato começou
# if not campeonato_comecou(ids_times):
#     print("📌 O campeonato ainda não começou. Criando estrutura com placeholders.")

#     total_rodadas = 38
#     df_pontuacoes = pd.DataFrame(index=ids_times.keys(), columns=[f'Rodada {i}' for i in range(1, total_rodadas + 1)])
#     df_pontuacoes[:] = 0  # ou None
# else:
#     def obter_pontuacao_por_rodada(time_id, rodada_atual):
#         pontuacoes = {}
#         for rodada in range(1, rodada_atual):
#             try:
#                 time_rodada = api.time(time_id=time_id, rodada=rodada)
#                 pontuacoes[rodada] = time_rodada.ultima_pontuacao
#             except cartolafc.errors.CartolaFCError as e:
#                 print(f"Erro ao acessar a pontuação da rodada {rodada} para o time {time_id}: {e}")
#                 pontuacoes[rodada] = None
#         return pontuacoes

#     df_pontuacoes = pd.DataFrame()

#     for nome, time_id in ids_times.items():
#         pontuacoes = obter_pontuacao_por_rodada(time_id, rodada_atual)
#         df_pontuacoes[nome] = pd.Series(pontuacoes)

#     df_pontuacoes = df_pontuacoes.transpose()
#     df_pontuacoes.columns = [f'Rodada {i}' for i in range(1, rodada_atual)]

#     lider_rodada = df_pontuacoes.idxmax()
#     df_pontuacoes.loc['Lider_Rodada'] = lider_rodada

# # Salvar em Excel
# excel_path = 'Pontuacoes_Por_Rodada_Liga_Classica.xlsx'
# df_pontuacoes.to_excel(excel_path)
# print(f"✅ Arquivo Excel salvo: {excel_path}")

# # Salvar em JS
# # Transforma o DataFrame em dicionário para JSON
# df_dict = df_pontuacoes.fillna("").to_dict(orient='index')
# js_content = f"const pontuacoesPorRodada = {json.dumps(df_dict, indent=2, ensure_ascii=False)};"

# js_path = "Pontuacoes_Por_Rodada_Liga_Classica.js"
# with open(js_path, "w", encoding="utf-8") as f:
#     f.write(js_content)
# print(f"✅ Arquivo JS salvo: {js_path}")

# # Exibir DataFrame
# display(df_pontuacoes.T)

import pandas as pd
import json

# Obter a rodada atual do mercado
rodada_atual = api.mercado().rodada_atual

# Função para verificar se o campeonato já começou (há pontuação na rodada 1)
def campeonato_comecou(ids_times):
    for time_id in ids_times.values():
        try:
            pontuacao = api.time(time_id=time_id, rodada=1).ultima_pontuacao
            if pontuacao is not None:
                return True
        except cartolafc.errors.CartolaFCError:
            continue
    return False

# Verifica se o campeonato começou
if not campeonato_comecou(ids_times):
    print("📌 O campeonato ainda não começou. Criando estrutura com placeholders.")

    total_rodadas = 38
    df_pontuacoes = pd.DataFrame(index=ids_times.keys(), columns=[f'Rodada {i}' for i in range(1, total_rodadas + 1)])
    df_pontuacoes[:] = 0  # ou None
else:
    def obter_pontuacao_por_rodada(time_id, rodada_atual):
        pontuacoes = {}
        for rodada in range(1, rodada_atual):
            try:
                time_rodada = api.time(time_id=time_id, rodada=rodada)
                pontuacoes[rodada] = time_rodada.ultima_pontuacao
            except cartolafc.errors.CartolaFCError as e:
                print(f"Erro ao acessar a pontuação da rodada {rodada} para o time {time_id}: {e}")
                pontuacoes[rodada] = None
        return pontuacoes

    df_pontuacoes = pd.DataFrame()

    for nome, time_id in ids_times.items():
        pontuacoes = obter_pontuacao_por_rodada(time_id, rodada_atual)
        df_pontuacoes[nome] = pd.Series(pontuacoes)

    df_pontuacoes = df_pontuacoes.transpose()
    df_pontuacoes.columns = [f'Rodada {i}' for i in range(1, rodada_atual)]

    lider_rodada = df_pontuacoes.idxmax()
    df_pontuacoes.loc['Lider_Rodada'] = lider_rodada

# ===============================
# 📊 Segmentação por Turnos e Meses
# ===============================

rodadas_por_mes = {
    "Março": [1],
    "Abril": [2, 3, 4, 5, 6],
    "Maio": [7, 8, 9, 10, 11],
    "Junho": [12],
    "Julho": [13, 14, 15, 16, 17],
    "Agosto": [18, 19, 20, 21, 22],
    "Setembro": [23, 24, 25],
    "Outubro": [26, 27, 28],
    "Novembro": [29, 30, 31, 32],
    "Dezembro": [33, 34, 35, 36, 37, 38],
}

rodadas_primeiro_turno = list(range(1, 20))
rodadas_segundo_turno = list(range(20, 39))

# Função para filtrar e somar pontuações
def somar_pontuacoes(df, rodadas):
    colunas = [f'Rodada {i}' for i in rodadas if f'Rodada {i}' in df.columns]
    return df[colunas].drop(index='Lider_Rodada', errors='ignore').sum(axis=1).sort_values(ascending=False)

# DataFrames por turno
df_turno_1 = df_pontuacoes[[f'Rodada {i}' for i in rodadas_primeiro_turno if f'Rodada {i}' in df_pontuacoes.columns]]
df_turno_2 = df_pontuacoes[[f'Rodada {i}' for i in rodadas_segundo_turno if f'Rodada {i}' in df_pontuacoes.columns]]

# Soma por turno
df_soma_turno_1 = somar_pontuacoes(df_pontuacoes, rodadas_primeiro_turno)
df_soma_turno_2 = somar_pontuacoes(df_pontuacoes, rodadas_segundo_turno)

# Soma por mês
df_soma_mensal = {}
for mes, rodadas in rodadas_por_mes.items():
    df_soma_mensal[mes] = somar_pontuacoes(df_pontuacoes, rodadas)

# ===============================
# 📁 Salvar tudo em Excel
# ===============================
with pd.ExcelWriter("Pontuacoes_Liga_Classica_Completa.xlsx") as writer:
    df_pontuacoes.to_excel(writer, sheet_name="Geral")
    df_turno_1.to_excel(writer, sheet_name="Turno 1")
    df_turno_2.to_excel(writer, sheet_name="Turno 2")
    pd.DataFrame(df_soma_turno_1).to_excel(writer, sheet_name="Classif Turno 1")
    pd.DataFrame(df_soma_turno_2).to_excel(writer, sheet_name="Classif Turno 2")
    for mes, serie in df_soma_mensal.items():
        pd.DataFrame(serie).to_excel(writer, sheet_name=f"Mês - {mes}")

print("✅ Arquivo Excel salvo com todas as segmentações.")

# ===============================
# 💾 Salvar em JS
# ===============================
df_dict_geral = df_pontuacoes.drop(index='Lider_Rodada', errors='ignore').fillna(0).to_dict(orient="index")

df_js = {
    "geral": df_dict_geral,
    "turnos": {
        "turno_1": df_soma_turno_1.to_dict(),
        "turno_2": df_soma_turno_2.to_dict(),
    },
    "meses": {mes: serie.to_dict() for mes, serie in df_soma_mensal.items()}
}

js_content = f"const classificacaoLigaClassica = {json.dumps(df_js, indent=2, ensure_ascii=False)};"

with open("Pontuacoes_Liga_Classica.js", "w", encoding="utf-8") as f:
    f.write(js_content)

print("✅ Arquivo JS salvo com estrutura geral, turnos e meses.")

# Exibir a pontuação geral transposta
display(df_pontuacoes.T)
# Out:
# ✅ Arquivo Excel salvo com todas as segmentações.
# ✅ Arquivo JS salvo com estrutura geral, turnos e meses.
# C:\Users\ferna\AppData\Local\Temp\ipykernel_21084\3457101499.py:167: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_dict_geral = df_pontuacoes.drop(index='Lider_Rodada', errors='ignore').fillna(0).to_dict(orient="index")
#          Real SCI Gig@ntte PraiaBravaFC OlhaEleAiF.C! Gremiomaniasm  \
# Rodada 1   104.09   100.34        96.39         96.19         95.23
# Rodada 2    75.69    86.39        96.19        102.99         59.22
# Rodada 3    87.02    86.80        87.05         54.12         95.55
#
#          Sport Clube PAIM PUXE FC RS Expressões da Arte ZIVI FC  \
# Rodada 1            93.85   84.69                 83.99   82.98
# Rodada 2            67.39   95.29                 92.82   60.45
# Rodada 3            85.52   86.95                 68.52   59.97
#
#          O clube do povo Itaqui/Rss F.C. Rei Das Copas Rolo Compressor ZN  \
# Rodada 1                      82.68              82.49              81.95
# Rodada 2                      82.02              82.84              74.49
# Rodada 3                      77.42              71.62              56.00
#
#          Taura da Fronteira FCIII Eleis-Itaqui KING LEONN Laranjja Mecannica  \
# Rodada 1                    80.25        79.95      79.30              78.80
# Rodada 2                    80.59        85.99      93.04              96.79
# Rodada 3                    58.62        48.30      84.70              80.10
#
#          Fedato Futebol Clube Perronee F.C Pity10 pra sempre imortal fc  \
# Rodada 1                77.58        76.79  75.33                 74.69
# Rodada 2                77.49        86.92  71.22                 68.19
# Rodada 3                75.42        58.60  90.20                 63.30
#
#          RHANKA DENTY FC25 TEAM LOPES 99 pura bucha /botafogo cartola scheuer  \
# Rodada 1             74.69         74.09                73.78           73.09
# Rodada 2             86.49         73.19                73.84           86.39
# Rodada 3             70.10         68.42                77.12           75.10
#
#          Analove10 ITAQUI GRANDE!!  ... E.C. Bororé Texas Club 2025  \
# Rodada 1                     72.59  ...       67.99           67.69
# Rodada 2                     76.19  ...       86.39           85.99
# Rodada 3                     67.40  ...       76.92           76.92
#
#          MAFRA MARTINS FC BordonFC Tatols Beants F.C FIGUEIRA DA ILHA  \
# Rodada 1            67.14    66.69             66.60            66.50
# Rodada 2            67.82    74.39             73.32           103.62
# Rodada 3            68.65    75.42             99.55            76.90
#
#          MauHumor F.C. A Lenda Super Vascão f.c TATITTA FC HS SPORTS F.C  \
# Rodada 1         66.20                    66.15      65.40         64.79
# Rodada 2        102.89                    76.48      59.68         94.48
# Rodada 3         74.30                    47.22      61.70         65.12
#
#          FBC Colorado Dom Camillo68 mercearia Estrela CosmoCity ZO  \
# Rodada 1        64.00         63.65             63.50        63.49
# Rodada 2        72.69         67.69             46.92        91.42
# Rodada 3        81.52         71.20             57.77        63.12
#
#          clarinvalau fc Grêmio imortal 37 SERGRILLO Super Vasco f.c  \
# Rodada 1          63.08             61.55     61.15           60.55
# Rodada 2          60.87             99.39    104.17           96.99
# Rodada 3          74.02             82.42     40.77           71.40
#
#          A Lenda Super Vasco F.c Paulo Virgili FC CALOMBO ITAQUI RS  \
# Rodada 1                   59.00            58.99             56.38
# Rodada 2                   88.29            55.18             80.62
# Rodada 3                   63.70            68.12             47.35
#
#          Luis lemes inter emer jr fc Cril Futebol Club       Lider_Rodada
# Rodada 1            53.64      50.03             47.93           Real SCI
# Rodada 2            80.97      60.88             79.69          SERGRILLO
# Rodada 3            68.55      56.00             59.72  Tatols Beants F.C
#
# [3 rows x 60 columns]

# %%
# Exibir a pontuação
display(df_pontuacoes)
# Out:
#                             Rodada 1   Rodada 2           Rodada 3
# Real SCI                      104.09      75.69              87.02
# Gig@ntte                      100.34      86.39              86.80
# PraiaBravaFC                   96.39      96.19              87.05
# OlhaEleAiF.C!                  96.19     102.99              54.12
# Gremiomaniasm                  95.23      59.22              95.55
# Sport Clube PAIM               93.85      67.39              85.52
# PUXE FC                        84.69      95.29              86.95
# RS Expressões da Arte          83.99      92.82              68.52
# ZIVI FC                        82.98      60.45              59.97
# O clube do povo Itaqui/Rss     82.68      82.02              77.42
# F.C. Rei Das Copas             82.49      82.84              71.62
# Rolo Compressor ZN             81.95      74.49              56.00
# Taura da Fronteira FCIII       80.25      80.59              58.62
# Eleis-Itaqui                   79.95      85.99              48.30
# KING LEONN                     79.30      93.04              84.70
# Laranjja Mecannica             78.80      96.79              80.10
# Fedato Futebol Clube           77.58      77.49              75.42
# Perronee F.C                   76.79      86.92              58.60
# Pity10                         75.33      71.22              90.20
# pra sempre imortal fc          74.69      68.19              63.30
# RHANKA DENTY FC25              74.69      86.49              70.10
# TEAM LOPES 99                  74.09      73.19              68.42
# pura bucha /botafogo           73.78      73.84              77.12
# cartola scheuer                73.09      86.39              75.10
# Analove10 ITAQUI GRANDE!!      72.59      76.19              67.40
# DM Studio                      72.55      81.69              82.67
# lsauer fc                      72.38      79.29              82.17
# VASCO MARTINS FC               72.29      56.82              91.99
# KP JUV.                        72.24     103.19              92.35
# BORGES ITAQUI F.C.             71.09      71.39              56.40
# Profit Soccer                  70.19      87.89              77.92
# Tabajara de Inhaua FC2         69.45      87.99              72.95
# TIGRE LEON                     69.40      83.04              83.60
# S.E.R. GRILLO                  68.48      81.12              53.84
# seralex                        68.40      72.89              38.22
# E.C. Bororé                    67.99      86.39              76.92
# Texas Club 2025                67.69      85.99              76.92
# MAFRA MARTINS FC               67.14      67.82              68.65
# BordonFC                       66.69      74.39              75.42
# Tatols Beants F.C              66.60      73.32              99.55
# FIGUEIRA DA ILHA               66.50     103.62              76.90
# MauHumor F.C.                  66.20     102.89              74.30
# A Lenda Super Vascão f.c       66.15      76.48              47.22
# TATITTA FC                     65.40      59.68              61.70
# HS SPORTS F.C                  64.79      94.48              65.12
# FBC Colorado                   64.00      72.69              81.52
# Dom Camillo68                  63.65      67.69              71.20
# mercearia Estrela              63.50      46.92              57.77
# CosmoCity ZO                   63.49      91.42              63.12
# clarinvalau fc                 63.08      60.87              74.02
# Grêmio imortal 37              61.55      99.39              82.42
# SERGRILLO                      61.15     104.17              40.77
# Super Vasco f.c                60.55      96.99              71.40
# A Lenda Super Vasco F.c        59.00      88.29              63.70
# Paulo Virgili FC               58.99      55.18              68.12
# CALOMBO ITAQUI RS              56.38      80.62              47.35
# Luis lemes inter               53.64      80.97              68.55
# emer jr fc                     50.03      60.88              56.00
# Cril Futebol Club              47.93      79.69              59.72
# Lider_Rodada                Real SCI  SERGRILLO  Tatols Beants F.C

# %% [markdown]
# ## Obter Escalação de um  Time em uma determinada Rodada

# %%
# Função auxiliar para verificar se a rodada teve pontuação real
def rodada_tem_pontuacao(api, ids_times, rodada):
    checagens = 0
    sem_pontuacao = 0

    for time_id in list(ids_times.values())[:5]:  # checa os 5 primeiros times apenas
        try:
            time_rodada = api.time(time_id=time_id, rodada=rodada)
            if not time_rodada.atletas or all(atleta.pontos in [None, 0.0] for atleta in time_rodada.atletas):
                sem_pontuacao += 1
            checagens += 1
            time.sleep(0.1)  # evitar sobrecarga
        except:
            continue

    return sem_pontuacao < checagens / 2  # só considera a rodada se a maioria tiver pontuação

# Função principal para obter a escalação de um time em uma rodada
def obter_escalacao_time(time_id, rodada):
    try:
        time_rodada = api.time(time_id=time_id, rodada=rodada)

        if not time_rodada.atletas:
            print(f"⚠️ Nenhum jogador encontrado para o time {time_id} na rodada {rodada}.")
            return []

        if all(atleta.pontos in [None, 0.0] for atleta in time_rodada.atletas):
            print(f"⏳ A rodada {rodada} ainda não ocorreu ou não teve pontuação computada.")
            return []

        jogadores = [
            {
                'Nome': atleta.apelido,
                'Posição': atleta.posicao.nome,
                'Pontos': atleta.pontos,
                'Clube': atleta.clube.nome
            }
            for atleta in time_rodada.atletas
        ]
        return jogadores

    except cartolafc.errors.CartolaFCError as e:
        print(f"Erro ao acessar a escalação da rodada {rodada} para o time {time_id}: {e}")
        return []

# Obter a rodada atual informada pela API
rodada_api = api.mercado().rodada_atual

# Ajustar para considerar apenas rodadas com pontuação finalizada
rodada_confirmada = rodada_api - 1
print(f"📌 A rodada {rodada_api} está em andamento. Coletando dados até a rodada {rodada_confirmada}.")

# Parâmetros
rodada_especifica = 1  # ou qualquer valor que você queira consultar
nome_time = 'Pity10'

# Verificações
if rodada_especifica > rodada_confirmada:
    print(f"⚠️ A Rodada {rodada_especifica} ainda não tem pontuação finalizada. Última rodada com dados válidos é a {rodada_confirmada}.")
elif nome_time not in ids_times:
    print(f"❌ O time '{nome_time}' não foi encontrado no dicionário de IDs.")
else:
    time_cartola = ids_times[nome_time]
    time_escalacao = obter_escalacao_time(time_cartola, rodada_especifica)

    if time_escalacao:
        df_escalacao = pd.DataFrame(time_escalacao)
        df_escalacao.sort_values(by='Posição', inplace=True)
        df_escalacao_pontuacao = df_escalacao['Pontos'].sum()

        print(f'✅ Time do Cartola: {nome_time}')
        print(f'📊 Pontuação na Rodada {rodada_especifica} (sem considerar Capitão): {df_escalacao_pontuacao:.2f}')
        display(df_escalacao.head(14))
    else:
        print("⚠️ Escalação vazia ou rodada ainda não computada.")
# Out:
# 📌 A rodada 4 está em andamento. Coletando dados até a rodada 3.
# ✅ Time do Cartola: Pity10
# 📊 Pontuação na Rodada 1 (sem considerar Capitão): 73.88
#               Nome   Posição  Pontos Clube
# 8          Gabriel  Atacante    8.80   CRU
# 9          Estêvão  Atacante    2.90   PAL
# 10         Marinho  Atacante    5.20   FOR
# 0           Cássio   Goleiro   10.20   CRU
# 1         Piquerez   Lateral    5.80   PAL
# 2          William   Lateral   19.30   CRU
# 5           Jadson      Meia    0.10   JUV
# 6       Hugo Moura      Meia    3.30   VAS
# 7       Jean Lucas      Meia    4.50   BAH
# 11    Fábio Matias   Técnico    8.98   JUV
# 3           Murilo  Zagueiro    3.40   PAL
# 4   Fabrício Bruno  Zagueiro    1.40   CRU

# %% [markdown]
# ## Obter Escalações Gerais

# %%
# Obter a rodada atual informada pela API
rodada_api = api.mercado().rodada_atual
rodada_confirmada = rodada_api - 1
print(f"📌 Rodada atual via API: {rodada_api} | Última rodada com pontuação confirmada: {rodada_confirmada}")

# Função para obter escalações de todos os times em todas as rodadas confirmadas
def obter_escalacoes_gerais(ids_times, rodada_confirmada):
    escalacoes_gerais = []

    for nome_time, time_id in ids_times.items():
        print(f"🔄 Coletando escalações para o time: {nome_time}")
        for rodada in range(1, rodada_confirmada + 1):
            escalação = obter_escalacao_time(time_id, rodada)

            if not escalação:
                print(f"⚠️ Rodada {rodada}: sem escalação disponível para {nome_time}.")
                continue

            for jogador in escalação:
                jogador['Time Cartola'] = nome_time
                jogador['Rodada'] = rodada
                escalacoes_gerais.append(jogador)

            # Evitar sobrecarga de requisições
            time.sleep(0.2)

    return escalacoes_gerais

# Obter escalações gerais até a rodada confirmada
escalacoes_gerais = obter_escalacoes_gerais(ids_times, rodada_confirmada)

# Armazenar em DataFrame
df_escalacoes = pd.DataFrame(escalacoes_gerais)

if df_escalacoes.empty:
    print("⚠️ Nenhuma escalação disponível até o momento. O DataFrame está vazio.")
else:
    # Organizar colunas
    colunas_ordenadas = ['Rodada', 'Time Cartola', 'Nome', 'Posição', 'Clube', 'Pontos']
    df_escalacoes = df_escalacoes[colunas_ordenadas]

    # Salvar em Excel
    df_escalacoes.to_excel('Escalacoes_Gerais_Liga_Classica.xlsx', index=False)
    print("✅ Arquivo 'Escalacoes_Gerais_Liga_Classica.xlsx' salvo com sucesso!")

# -------------------------------------------------------------------------------------------------------------------------------------------#
    # Estrutura para agrupar por rodada
    dados_js = {}

    for rodada, df_rodada in df_escalacoes.groupby('Rodada'):
        dados_js[f'Rodada {rodada}'] = df_rodada.to_dict(orient='records')

    # Converter em string JS
    js_content = f"const escalacoesSerieA = {json.dumps(dados_js, indent=2, ensure_ascii=False)};"

    # Salvar em .js
    js_path = "Escalacoes_Gerais_Liga_Classica.js"
    with open(js_path, "w", encoding="utf-8") as f:
        f.write(js_content)

# -------------------------------------------------------------------------------------------------------------------------------------------#

    # Visualizar primeiras linhas
    display(df_escalacoes.head())
# Out:
# 📌 Rodada atual via API: 4 | Última rodada com pontuação confirmada: 3
# 🔄 Coletando escalações para o time: Real SCI
# 🔄 Coletando escalações para o time: Gig@ntte
# 🔄 Coletando escalações para o time: PraiaBravaFC
# 🔄 Coletando escalações para o time: OlhaEleAiF.C!
# 🔄 Coletando escalações para o time: Gremiomaniasm
# 🔄 Coletando escalações para o time: Sport Clube PAIM
# 🔄 Coletando escalações para o time: PUXE FC
# 🔄 Coletando escalações para o time: RS Expressões da Arte
# 🔄 Coletando escalações para o time: ZIVI FC
# 🔄 Coletando escalações para o time: O clube do povo Itaqui/Rss
# 🔄 Coletando escalações para o time: F.C. Rei Das Copas
# 🔄 Coletando escalações para o time: Rolo Compressor ZN
# 🔄 Coletando escalações para o time: Taura da Fronteira FCIII
# 🔄 Coletando escalações para o time: Eleis-Itaqui
# 🔄 Coletando escalações para o time: KING LEONN
# 🔄 Coletando escalações para o time: Laranjja Mecannica
# 🔄 Coletando escalações para o time: Fedato Futebol Clube
# 🔄 Coletando escalações para o time: Perronee F.C
# 🔄 Coletando escalações para o time: Pity10
# 🔄 Coletando escalações para o time: pra sempre imortal fc
# 🔄 Coletando escalações para o time: RHANKA DENTY FC25
# 🔄 Coletando escalações para o time: TEAM LOPES 99
# 🔄 Coletando escalações para o time: pura bucha /botafogo
# 🔄 Coletando escalações para o time: cartola scheuer
# 🔄 Coletando escalações para o time: Analove10 ITAQUI GRANDE!!
# 🔄 Coletando escalações para o time: DM Studio
# 🔄 Coletando escalações para o time: lsauer fc
# 🔄 Coletando escalações para o time: VASCO MARTINS FC
# 🔄 Coletando escalações para o time: KP JUV.
# 🔄 Coletando escalações para o time: BORGES ITAQUI F.C.
# 🔄 Coletando escalações para o time: Profit Soccer
# 🔄 Coletando escalações para o time: Tabajara de Inhaua FC2
# 🔄 Coletando escalações para o time: TIGRE LEON
# 🔄 Coletando escalações para o time: S.E.R. GRILLO
# 🔄 Coletando escalações para o time: seralex
# 🔄 Coletando escalações para o time: E.C. Bororé
# 🔄 Coletando escalações para o time: Texas Club 2025
# 🔄 Coletando escalações para o time: MAFRA MARTINS FC
# 🔄 Coletando escalações para o time: BordonFC
# 🔄 Coletando escalações para o time: Tatols Beants F.C
# 🔄 Coletando escalações para o time: FIGUEIRA DA ILHA
# 🔄 Coletando escalações para o time: MauHumor F.C.
# 🔄 Coletando escalações para o time: A Lenda Super Vascão f.c
# 🔄 Coletando escalações para o time: TATITTA FC
# 🔄 Coletando escalações para o time: HS SPORTS F.C
# 🔄 Coletando escalações para o time: FBC Colorado
# 🔄 Coletando escalações para o time: Dom Camillo68
# 🔄 Coletando escalações para o time: mercearia Estrela
# 🔄 Coletando escalações para o time: CosmoCity ZO
# 🔄 Coletando escalações para o time: clarinvalau fc
# 🔄 Coletando escalações para o time: Grêmio imortal 37
# 🔄 Coletando escalações para o time: SERGRILLO
# 🔄 Coletando escalações para o time: Super Vasco f.c
# 🔄 Coletando escalações para o time: A Lenda Super Vasco F.c
# 🔄 Coletando escalações para o time: Paulo Virgili FC
# 🔄 Coletando escalações para o time: CALOMBO ITAQUI RS
# 🔄 Coletando escalações para o time: Luis lemes inter
# 🔄 Coletando escalações para o time: emer jr fc
# 🔄 Coletando escalações para o time: Cril Futebol Club
# ✅ Arquivo 'Escalacoes_Gerais_Liga_Classica.xlsx' salvo com sucesso!
#    Rodada Time Cartola              Nome   Posição Clube  Pontos
# 0       1     Real SCI          Weverton   Goleiro   PAL   11.50
# 1       1     Real SCI  Juninho Capixaba   Lateral   RBB    7.40
# 2       1     Real SCI           William   Lateral   CRU   19.30
# 3       1     Real SCI            Murilo  Zagueiro   PAL    3.40
# 4       1     Real SCI             Abner  Zagueiro   JUV   13.00

# %% [markdown]
# ## Função para listar os jogadores mais escalados por posição

# %%
# Função para listar os jogadores mais escalados por posição
def listar_jogadores_mais_escalados(df, n_goleiros=3, n_zagueiros=4, n_laterais=4, n_meias=5, n_atacantes=5):
    if df.empty:
        print("⚠️ O DataFrame está vazio. Nenhuma escalação disponível ainda.")
        return pd.DataFrame()

    # Agrupar por nome, posição e clube
    df_agrupado = df.groupby(['Nome', 'Posição', 'Clube'], as_index=False).agg(
        Pontos=('Pontos', 'sum'),
        Quantidade=('Nome', 'size')
    )

    # Filtrar por posição
    goleiros = df_agrupado[df_agrupado['Posição'] == 'Goleiro'].sort_values(by='Quantidade', ascending=False).head(n_goleiros)
    zagueiros = df_agrupado[df_agrupado['Posição'] == 'Zagueiro'].sort_values(by='Quantidade', ascending=False).head(n_zagueiros)
    laterais = df_agrupado[df_agrupado['Posição'] == 'Lateral'].sort_values(by='Quantidade', ascending=False).head(n_laterais)
    meias = df_agrupado[df_agrupado['Posição'] == 'Meia'].sort_values(by='Quantidade', ascending=False).head(n_meias)
    atacantes = df_agrupado[df_agrupado['Posição'] == 'Atacante'].sort_values(by='Quantidade', ascending=False).head(n_atacantes)

    # Concatenar todos os jogadores
    jogadores_mais_escalados = pd.concat([goleiros, zagueiros, laterais, meias, atacantes])

    # colunas = ['Nome', 'Posição', 'Clube', 'Quantidade', 'Pontos']
    colunas = ['Nome', 'Posição', 'Clube', 'Quantidade']
    jogadores_mais_escalados = jogadores_mais_escalados[colunas]

    return jogadores_mais_escalados

# Execução com verificação
jogadores_mais_escalados = listar_jogadores_mais_escalados(df_escalacoes)

if not jogadores_mais_escalados.empty:
    print("📋 Jogadores mais escalados por posição:")
    display(jogadores_mais_escalados.head(10))

    # 🔹 Salvar em Excel
    jogadores_mais_escalados.to_excel("Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.xlsx", index=False)
    print("✅ Arquivo 'Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.xlsx' salvo com sucesso.")

    # 🔹 Salvar em JavaScript (.js)
    js_mais_escalados = jogadores_mais_escalados.to_dict(orient="records")
    js_content = f"const jogadoresMaisEscaladosPorPosicao = {json.dumps(js_mais_escalados, indent=2, ensure_ascii=False)};"

    with open("Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.js", "w", encoding="utf-8") as f:
        f.write(js_content)
    print("✅ Arquivo 'Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.js' salvo com sucesso.")
else:
    print("⚠️ Nenhum jogador encontrado para salvar.")
# Out:
# 📋 Jogadores mais escalados por posição:
#                  Nome   Posição Clube  Quantidade
# 209          Weverton   Goleiro   PAL          46
# 179           Ronaldo   Goleiro   BAH          42
# 13            Anthoni   Goleiro   INT          33
# 132         Léo Ortiz  Zagueiro   FLA          63
# 110     Junior Alonso  Zagueiro   CAM          46
# 113              Kanu  Zagueiro   BAH          32
# 14           Arboleda  Zagueiro   SAO          26
# 109  Juninho Capixaba   Lateral   RBB          66
# 153          Natanael   Lateral   CAM          32
# 208            Wesley   Lateral   FLA          29
# ✅ Arquivo 'Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.xlsx' salvo com sucesso.
# ✅ Arquivo 'Jogadores_Mais_Escalados_Por_Posicao_Liga_Classica.js' salvo com sucesso.

# %% [markdown]
# ## Função para listar os times que mais escalaram um determinado jogador

# %%
# Função para listar os times que mais escalaram um determinado jogador
def listar_times_que_mais_escalaram(df, nome_jogador, clube_jogador):
    if df.empty:
        print("⚠️ O DataFrame está vazio. Nenhum dado disponível para análise.")
        return pd.DataFrame()
    
    df_jogador = df[(df['Nome'] == nome_jogador) & (df['Clube'] == clube_jogador)]

    if df_jogador.empty:
        print(f"⚠️ Nenhuma escalação encontrada para o jogador '{nome_jogador}' do clube '{clube_jogador}'.")
        return pd.DataFrame()

    df_times_que_mais_escalaram = df_jogador.groupby('Time Cartola', as_index=False).agg(
        Quantidade=('Nome', 'size')
    ).sort_values(by='Quantidade', ascending=False)
    
    return df_times_que_mais_escalaram

# Exemplo de uso
nome_jogador = "Weverton"
clube_jogador = "PAL"

times_que_mais_escalaram = listar_times_que_mais_escalaram(df_escalacoes, nome_jogador, clube_jogador)

if not times_que_mais_escalaram.empty:
    print(f"📊 Times que mais escalaram o jogador {nome_jogador} ({clube_jogador}):")
    display(times_que_mais_escalaram)
# Out:
# 📊 Times que mais escalaram o jogador Weverton (PAL):
#                   Time Cartola  Quantidade
# 12            FIGUEIRA DA ILHA           2
# 25            Sport Clube PAIM           2
# 28               TEAM LOPES 99           2
# 7                Dom Camillo68           2
# 10          F.C. Rei Das Copas           2
# 13                    Gig@ntte           2
# 0      A Lenda Super Vasco F.c           1
# 24          Rolo Compressor ZN           1
# 26             Super Vasco f.c           1
# 27                  TATITTA FC           1
# 29                  TIGRE LEON           1
# 30      Tabajara de Inhaua FC2           1
# 31           Tatols Beants F.C           1
# 22           RHANKA DENTY FC25           1
# 32    Taura da Fronteira FCIII           1
# 33             Texas Club 2025           1
# 34             cartola scheuer           1
# 35              clarinvalau fc           1
# 36                  emer jr fc           1
# 37                   lsauer fc           1
# 38       pra sempre imortal fc           1
# 23                    Real SCI           1
# 20                PraiaBravaFC           1
# 21               Profit Soccer           1
# 9                 Eleis-Itaqui           1
# 2    Analove10 ITAQUI GRANDE!!           1
# 3           BORGES ITAQUI F.C.           1
# 4                     BordonFC           1
# 5                 CosmoCity ZO           1
# 6                    DM Studio           1
# 8                  E.C. Bororé           1
# 11                FBC Colorado           1
# 1     A Lenda Super Vascão f.c           1
# 14               HS SPORTS F.C           1
# 15                  KING LEONN           1
# 16               MauHumor F.C.           1
# 17  O clube do povo Itaqui/Rss           1
# 18            Paulo Virgili FC           1
# 19                Perronee F.C           1
# 39                     seralex           1

# %% [markdown]
# ## Função para Listar Jogadores Agrupados por 'Time Cartola'  e Posição

# %%
# Função para listar todos os jogadores escalados por um determinado time, agrupados por posição, nome e clube
def listar_jogadores_escalados_por_time_e_agrupados(df, nome_time, posicao=None):
    if df.empty:
        print("⚠️ O DataFrame está vazio. Nenhum dado disponível para análise.")
        return pd.DataFrame()
    
    if nome_time not in df['Time Cartola'].unique():
        print(f"⚠️ O time '{nome_time}' não possui escalações registradas.")
        return pd.DataFrame()

    df_time = df[df['Time Cartola'] == nome_time]
    
    if posicao:
        df_time = df_time[df_time['Posição'] == posicao]
        if df_time.empty:
            print(f"⚠️ Nenhum jogador na posição '{posicao}' encontrado para o time '{nome_time}'.")
            return pd.DataFrame()

    df_agrupado = df_time.groupby(['Nome', 'Posição', 'Clube'], as_index=False).agg(
        Pontos=('Pontos', 'sum'),
        Quantidade=('Nome', 'size')
    )

    df_agrupado = df_agrupado.sort_values(by='Quantidade', ascending=False)

    return df_agrupado

# Exemplo de uso
nome_time = "Real SCI"
posicao = 'Atacante'  # Substitua por outra posição ou deixe como None

jogadores_escalados_agrupados = listar_jogadores_escalados_por_time_e_agrupados(df_escalacoes, nome_time, posicao)

if not jogadores_escalados_agrupados.empty:
    display(jogadores_escalados_agrupados.head(20))
# Out:
#            Nome   Posição Clube  Pontos  Quantidade
# 1          Hulk  Atacante   CAM    9.10           2
# 4          Rony  Atacante   CAM   18.40           2
# 0       Gabriel  Atacante   CRU    8.80           1
# 2    Igor Jesus  Atacante   BOT   10.60           1
# 3    Kaio Jorge  Atacante   CRU    5.60           1
# 5       Vegetti  Atacante   VAS   18.20           1
# 6  Yuri Alberto  Atacante   COR   12.80           1

# %% [markdown]
# ### Função para listar os jogadores mais escalados por posição para um determinado time do Cartola

# %%
# Função para listar os jogadores mais escalados por posição para um determinado time do Cartola
def listar_jogadores_mais_escalados_por_posicao(df, nome_time, top_n=3):
    if df.empty:
        print("⚠️ O DataFrame está vazio. Nenhum dado disponível.")
        return pd.DataFrame()

    if nome_time not in df['Time Cartola'].unique():
        print(f"⚠️ O time '{nome_time}' não possui escalações registradas.")
        return pd.DataFrame()

    df_time = df[df['Time Cartola'] == nome_time].copy()

    df_agrupado = df_time.groupby(['Posição', 'Nome', 'Clube'], as_index=False).agg(
        Pontos=('Pontos', 'sum'),
        Quantidade=('Nome', 'size')
    )

    # Ordenar por posição e quantidade
    df_agrupado = df_agrupado.sort_values(by=['Posição', 'Quantidade'], ascending=[True, False])

    # Selecionar os top N jogadores para cada posição
    df_top_n_por_posicao = df_agrupado.groupby('Posição').head(top_n).copy()

    # Definir a ordem específica das posições
    ordem_posicoes = ['Goleiro', 'Lateral', 'Zagueiro', 'Meia', 'Atacante', 'Técnico']
    df_top_n_por_posicao['Posição'] = pd.Categorical(df_top_n_por_posicao['Posição'], categories=ordem_posicoes, ordered=True)

    # Ordenar conforme a ordem definida
    df_top_n_por_posicao = df_top_n_por_posicao.sort_values(by=['Posição', 'Quantidade'], ascending=[True, False])

    return df_top_n_por_posicao

# Função para calcular a pontuação total e média por posição
def calcular_pontuacao_total_e_media(df_jogadores):
    if df_jogadores.empty:
        print("⚠️ Sem dados de jogadores para cálculo de pontuação.")
        return pd.DataFrame()

    df_total_pontuacao = df_jogadores.groupby('Posição', observed=True).agg(
        Pontuacao_Total=('Pontos', 'sum'),
        Quantidade=('Quantidade', 'sum')
    ).reset_index()

    df_total_pontuacao['Pontuacao_Media'] = df_total_pontuacao['Pontuacao_Total'] / df_total_pontuacao['Quantidade']

    # Definir ordem de exibição
    ordem_posicoes = ['Goleiro', 'Lateral', 'Zagueiro', 'Meia', 'Atacante', 'Técnico']
    df_total_pontuacao['Posição'] = pd.Categorical(df_total_pontuacao['Posição'], categories=ordem_posicoes, ordered=True)
    df_total_pontuacao = df_total_pontuacao.sort_values(by='Posição')

    return df_total_pontuacao

# %%
nome_time = "Real SCI"
top_n = 4  # Altere se quiser

jogadores_mais_escalados_por_posicao = listar_jogadores_mais_escalados_por_posicao(df_escalacoes, nome_time, top_n)

if not jogadores_mais_escalados_por_posicao.empty:
    print(f"📋 Jogadores mais escalados por posição para o time {nome_time}:")
    display(jogadores_mais_escalados_por_posicao)

    pontuacao_total_e_media = calcular_pontuacao_total_e_media(jogadores_mais_escalados_por_posicao)

    print("📊 Pontuação total e média por posição:")
    display(pontuacao_total_e_media)
# Out:
# 📋 Jogadores mais escalados por posição para o time Real SCI:
#      Posição               Nome Clube  Pontos  Quantidade
# 7    Goleiro            Anthoni   INT   12.60           2
# 8    Goleiro           Weverton   PAL   11.50           1
# 12   Lateral             Wesley   FLA    7.50           2
# 9    Lateral    Guilherme Arana   CAM    2.50           1
# 10   Lateral   Juninho Capixaba   RBB    7.40           1
# 11   Lateral        Matheuzinho   COR    8.70           1
# 24  Zagueiro              Abner   JUV   13.00           1
# 25  Zagueiro  Alexander Barboza   BOT    8.20           1
# 26  Zagueiro      Junior Alonso   CAM    0.80           1
# 27  Zagueiro             Micael   PAL    2.00           1
# 14      Meia              Arias   FLU   12.00           2
# 17      Meia         Jean Lucas   BAH    9.80           2
# 15      Meia         Arrascaeta   FLA   16.50           1
# 16      Meia      Igor Coronado   COR    2.00           1
# 1   Atacante               Hulk   CAM    9.10           2
# 4   Atacante               Rony   CAM   18.40           2
# 0   Atacante            Gabriel   CRU    8.80           1
# 2   Atacante         Igor Jesus   BOT   10.60           1
# 21   Técnico       Fábio Matias   JUV    5.57           1
# 22   Técnico    Leonardo Jardim   CRU    7.59           1
# 23   Técnico       Renato Paiva   BOT    9.49           1
# 📊 Pontuação total e média por posição:
#     Posição  Pontuacao_Total  Quantidade  Pontuacao_Media
# 0   Goleiro            24.10           3             8.03
# 1   Lateral            26.10           5             5.22
# 2  Zagueiro            24.00           4             6.00
# 3      Meia            40.30           6             6.72
# 4  Atacante            46.90           6             7.82
# 5   Técnico            22.65           3             7.55
